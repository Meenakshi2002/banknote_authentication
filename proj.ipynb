# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenakshi2002/banknote_authentication/blob/main/proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans
url="https://raw.githubusercontent.com/Meenakshi2002/crime-rate/main/data-set.csv"
data = pd.read_csv(url)
data_normalised= (data-data.min())/(data.max()-data.min())
#print(data_normalised.head(10))

#cluster

x=data_normalised['V1']
y=data_normalised['V2']
xy=np.column_stack((x,y))

cluster =KMeans(n_clusters=2).fit(xy)
centers=cluster.cluster_centers_
#print(centers)

cluster_fit =KMeans(n_clusters=2).fit_predict(xy)
data_normalised['cluster']=cluster_fit
#print(cluster_fit)

plt.scatter(x,y,c=cluster_fit)
plt.scatter(centers[:,0],centers[:,1],s=400)
plt.show()
print(centers)
print(data_normalised['cluster'].value_counts())
# Out:
# [[0.3706405  0.44853981]
#  [0.67437924 0.69871178]]
# 0    764
# 1    608
# Name: cluster, dtype: int64
